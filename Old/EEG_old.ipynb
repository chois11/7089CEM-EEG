# %% [markdown]
# # This notebook is created for part of Coventy University's 7089CEM coursework
#
# Made by Sunggu Choi

# %%
# Data pre-processing

# %%
# Load required libaraies 
library(plotly)

# %%
eeg_x = read.csv("x.csv", header = FALSE)
eeg_y = read.csv("y.csv", header = FALSE)
eeg_time = read.csv("time.csv", header = FALSE)

# #fix time
# time = read.csv("time.csv", header = FALSE, skip = 1)
# time = rbind(0, time)

# %%
head(x)
# Out:
#   V1         V2         V3          V4
# 1 -3.0615656 -1.8651967 -2.90981227 -0.3394280
# 2  0.2446936  2.0391609  0.99930151  0.6122276
# 3 -1.2009670  0.1774090 -0.79654755 -2.6770103
# 4 -0.7279816 -1.5566153  0.01039548 -1.6230083
# 5  2.2049284  0.7661962  1.86810725  1.4313685
# 6  3.1672849  1.8484216  1.73971053  2.4726877

# %%
head(eeg_time)
# Out:
#   V1
# 1 0.000
# 2 0.002
# 3 0.004
# 4 0.006
# 5 0.008
# 6 0.010

# %%
# Data manipulation
eeg_combined <- cbind(eeg_time, eeg_x, eeg_y)
eeg_x_with_time <- cbind(eeg_time, eeg_x)
eeg_x_y <- cbind(eeg_x, eeg_y)

# %%
typeof(eeg_combined)
# Out:
# [1] "list"

# %%
head(eeg_combined)
# Out:
#   V1    V1         V2         V3          V4         V1
# 1 0.000 -3.0615656 -1.8651967 -2.90981227 -0.3394280 -1.11678535
# 2 0.002  0.2446936  2.0391609  0.99930151  0.6122276  1.33388908
# 3 0.004 -1.2009670  0.1774090 -0.79654755 -2.6770103  0.21606254
# 4 0.006 -0.7279816 -1.5566153  0.01039548 -1.6230083  0.17645157
# 5 0.008  2.2049284  0.7661962  1.86810725  1.4313685  0.01104331
# 6 0.010  3.1672849  1.8484216  1.73971053  2.4726877  1.03716149

# %%
plot(eeg_combined)
# Out:
# plot without title

# %%
matplot(eeg_input_and_output, type = c("b"),pch=1,col = 1:4) #plot
legend("topleft", legend = 1:4, col=1:4, pch=1) # optional legend
# Out:
# Error in matplot(eeg_input_and_output, type = c("b"), pch = 1, col = 1:4): object 'eeg_input_and_output' not found
# Traceback:
#
# 1. matplot(eeg_input_and_output, type = c("b"), pch = 1, col = 1:4)

# %%
str(eeg_combined)
# Out:
# 'data.frame':	201 obs. of  6 variables:
#  $ V1: num  0 0.002 0.004 0.006 0.008 0.01 0.012 0.014 0.016 0.018 ...
#  $ V1: num  -3.062 0.245 -1.201 -0.728 2.205 ...
#  $ V2: num  -1.865 2.039 0.177 -1.557 0.766 ...
#  $ V3: num  -2.9098 0.9993 -0.7965 0.0104 1.8681 ...
#  $ V4: num  -0.339 0.612 -2.677 -1.623 1.431 ...
#  $ V1: num  -1.117 1.334 0.216 0.176 0.011 ...

# %%
matplot(eeg_time, eeg_x[1], type="l",col=c("red","green"),lty=c(1,1))
matplot(eeg_time, cbind(eeg_x[2]), type="l",col=c("red","green"),lty=c(1,1))
matplot(eeg_time, cbind(eeg_x[3]), type="l",col=c("red","green"),lty=c(1,1))
matplot(eeg_time, cbind(eeg_x[4]), type="l",col=c("red","green"),lty=c(1,1))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# Out:
# Error in stripchart.default(x1, ...): invalid plotting method
# Traceback:
#
# 1. plot(eeg_time, eeg_x, type = "l", col = "red")
# 2. plot.data.frame(eeg_time, eeg_x, type = "l", col = "red")
# 3. stripchart(x1, ...)
# 4. stripchart.default(x1, ...)
# 5. stop("invalid plotting method")
